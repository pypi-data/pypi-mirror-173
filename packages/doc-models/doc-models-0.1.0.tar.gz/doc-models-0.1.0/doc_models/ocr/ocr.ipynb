# %%
import pytesseract
from PIL import Image
from pytesseract import Output
import cv2
from doc_models.types import WriteOnceDict
from pathlib import Path

# %%
for f in list(Path('/home/dan/images/Upwork Docs').glob('*.Identifier')):
    f.unlink()

# %%
file = '/home/dan/my-github-packages/pdf-extract/aapl8k_images/aapl8k1-1.jpg'

# %%
img = cv2.imread(file)
# TODO filter.
data = pytesseract.image_to_data(img, output_type=Output.DICT)

# %%
fields = [
    "level",
    "page_num",
    "block_num",
    'par_num',
    "line_num",
    "left",
    "top",
    "width",
    "height",
    "conf",
    "text",
]
data = [dict(zip(fields, row)) for row in zip(*[data[f] for f in fields])]

# %%
{d['level'] for d in data}
# Out:
# {1, 2, 3, 4, 5}

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df.head(1000)
# Out:
#      level  page_num  block_num  par_num  line_num  left   top  width  height  \
# 0        1         1          0        0         0     0     0   2342    3312
# 1        2         1          1        0         0    76    45    177      19
# 2        3         1          1        1         0    76    45    177      19
# 3        4         1          1        1         1    76    45    177      19
# 4        5         1          1        1         1    76    45     76      19
# ..     ...       ...        ...      ...       ...   ...   ...    ...     ...
# 582      5         1         43        1         1    75  3247    960      21
# 583      2         1         44        0         0  2239  3247     25      16
# 584      3         1         44        1         0  2239  3247     25      16
# 585      4         1         44        1         1  2239  3247     25      16
# 586      5         1         44        1         1  2239  3247     25      16
#
# ...
